# %% [markdown]
# # WeatherPy
# ----
#
# ### Analysis
# * As expected, the weather becomes significantly warmer as one approaches the equator (0 Deg. Latitude). More interestingly, however, is the fact that the southern hemisphere tends to be warmer this time of year than the northern hemisphere. This may be due to the tilt of the earth.
# * There is no strong relationship between latitude and cloudiness. However, it is interesting to see that a strong band of cities sits at 0, 80, and 100% cloudiness.
# * There is no strong relationship between latitude and wind speed. However, in northern hemispheres there is a flurry of cities with over 20 mph of wind.
#
# ---
#
# #### Note
# * Instructions have been included for each segment. You do not have to follow them exactly, but they are included to help you think through the steps.

# %%
# Dependencies and Setup
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import requests
import time

# Import API key
import api_keys

# Incorporated citipy to determine city based on latitude and longitude
from citipy import citipy

# Output File (CSV)
output_data_file = "output_data/cities.csv"

# Range of latitudes and longitudes
lat_range = (-90, 90)
lng_range = (-180, 180)

# %% [markdown]
# ## Generate Cities List

# %%
# List for holding lat_lngs and cities
lat_lngs = []
cities = []

# Create a set of random lat and lng combinations
lats = np.random.uniform(low=-90.000, high=90.000, size=1500)
lngs = np.random.uniform(low=-180.000, high=180.000, size=1500)
lat_lngs = zip(lats, lngs)

# Identify nearest city for each lat, lng combination
for lat_lng in lat_lngs:
    city = citipy.nearest_city(lat_lng[0], lat_lng[1]).city_name
    
    # If the city is unique, then add it to a our cities list
    if city not in cities:
        cities.append(city)

# Print the city count to confirm sufficient count
len(cities)
# Out:
# 640

# %% [markdown]
# ### Perform API Calls
# * Perform a weather check on each city using a series of successive API calls.
# * Include a print log of each city as it'sbeing processed (with the city number and city name).

# %%
lists=[]
for x in cities:
    url="http://api.openweathermap.org/data/2.5/weather?q="+ x + "&APPID=" +"99e15d2a53b3bedd876f9ea0f6b7ad30"
    cityweather=requests.get(url).json()
    lists.append(cityweather)
lists
# Out:
# [{'coord': {'lon': 20.04, 'lat': -34.53},
#   'weather': [{'id': 800,
#     'main': 'Clear',
#     'description': 'clear sky',
#     'icon': '01d'}],
#   'base': 'stations',
#   'main': {'temp': 301.15,
#    'pressure': 1012,
#    'humidity': 51,
#    'temp_min': 301.15,
#    'temp_max': 301.15},
#   'wind': {'speed': 6.2, 'deg': 160},
#   'clouds': {'all': 0},
#   'dt': 1546261200,
#   'sys': {'type': 1,
#    'id': 1966,
#    'message': 0.0052,
#    'country': 'ZA',
#    'sunrise': 1546227009,
#    'sunset': 1546278946},
#   'id': 1015776,
#   'name': 'Bredasdorp',
#   'cod': 200},
#  {'coord': {'lon': 26.89, 'lat': -33.59},
#   'weather': [{'id': 800,
#     'main': 'Clear',
#     'description': 'clear sky',
#     'icon': '01d'}],
#   'base': 'stations',
#   'main': {'temp': 298.483,
#    'pressure': 1018.46,
#    'humidity': 76,
#    'temp_min': 298.483,
#    'temp_max': 298.483,
#    'sea_level': 1027.17,
#    'grnd_level': 1018.46},
#   'wind': {'speed': 5.72, 'deg': 87.0007},
# ...

# %% [markdown]
# ### Convert Raw Data to DataFrame
# * Export the city data into a .csv.
# * Display the DataFrame

# %%
#city name
Cityname=[]
for y in lists:
    try:
        Cityname.append(y["name"])
    except KeyError:
        y=[]
        
city_df=pd.DataFrame({"City":Cityname})

#clouds
cloudiness=[]
for x in lists:
    try:
        cloudiness.append(x["clouds"])
    except KeyError:
        x=[]
        
cloudiness_df=pd.DataFrame(cloudiness)
cloudiness_df["Cloudiness"]=cloudiness_df["all"]
cloudiness_df=cloudiness_df.drop(columns=["all"])
city_df["Cloudiness"]=cloudiness_df

#country
countries=[]
for x in lists:
    try:
        countries.append(x["sys"]["country"])
    except KeyError:
        x=[]
city_df["Countries"]=countries

#date
date=[]
for x in lists:
    try:
        date.append(x["dt"])
    except KeyError:
        x=[]
city_df["Date"]=date

#lat
lats=[]
for x in lists:
    try:
        lats.append(x["coord"]["lat"])
    except KeyError:
        x=[]
city_df["Lat"]=lats

#lng
lng=[]
for x in lists:
    try:
        lng.append(x["coord"]["lon"])
    except KeyError:
        x=[]
city_df["Lng"]=lng


#temp
temp=[]
for x in lists:
    try:
        temp.append(x["main"]["temp_max"])
    except KeyError:
        x=[]
city_df["Max Temp"]=temp


#wind
wind=[]
for x in lists:
    try:
        wind.append(x["wind"]["speed"])
    except KeyError:
        x=[]
city_df["Wind Speed"]=wind

#Humid
humid=[]
for x in lists:
    try:
        humid.append(x["main"]["humidity"])
    except KeyError:
        x=[]
city_df["Humidity"]=humid

city_df.head(10)
# Out:
#              City  Cloudiness Countries        Date    Lat     Lng  Max Temp  \
# 0      Bredasdorp           0        ZA  1546261200 -34.53   20.04   301.150
# 1     Port Alfred           0        ZA  1546262755 -33.59   26.89   298.483
# 2    Punta Arenas          75        CL  1546261200 -53.16  -70.91   287.150
# 3         Rikitea          80        PF  1546263355 -23.12 -134.97   298.716
# 4       Toppenish           1        US  1546262100  46.38 -120.31   275.850
# 5        Hermanus           0        ZA  1546263356 -34.42   19.24   303.216
# 6  Cabo San Lucas           5        MX  1546260660  22.89 -109.91   285.150
# 7          Kupang          75        ID  1546261200 -10.16  123.60   299.150
# 8          Lompoc          90        US  1546262100  34.64 -120.46   284.250
# 9       Upernavik          32        GL  1546263357  72.79  -56.15   264.366
#
#    Wind Speed  Humidity
# 0        6.20        51
# 1        5.72        76
# 2        6.70        44
# ...

# %% [markdown]
# ### Plotting the Data
# * Use proper labeling of the plots using plot titles (including date of analysis) and axes labels.
# * Save the plotted figures as .pngs.

# %% [markdown]
# #### Latitude vs. Temperature Plot

# %%
x_axis=np.arange(0, len(city_df["Lat"]))
plt.scatter(x_axis, city_df["Max Temp"])
plt.grid()
plt.xlabel("Latitude")
plt.ylabel("Max Temperature")
plt.title("City Latitude versus Max Temperature")
# Out:
# Text(0.5,1,'City Latitude versus Max Temperature')

# %% [markdown]
# #### Latitude vs. Humidity Plot

# %%
plt.scatter(x_axis, city_df["Humidity"])
plt.grid()
plt.xlabel("Latitude")
plt.ylabel("Humidity(%)")
plt.title("City Latitude versus Humidity")
# Out:
# Text(0.5,1,'City Latitude versus Humidity')

# %% [markdown]
# #### Latitude vs. Cloudiness Plot

# %%
plt.scatter(x_axis, city_df["Cloudiness"])
plt.grid()
plt.xlabel("Latitude")
plt.ylabel("Cloudiness (%)")
plt.title("City Latitude versus Cloudiness")
# Out:
# Text(0.5,1,'City Latitude versus Cloudiness')

# %% [markdown]
# #### Latitude vs. Wind Speed Plot

# %%
plt.scatter(x_axis, city_df["Wind Speed"])
plt.grid()
plt.xlabel("Latitude")
plt.ylabel("Wind Speed")
plt.title("City Latitude versus Wind Speed")
# Out:
# Text(0.5,1,'City Latitude versus Wind Speed')
